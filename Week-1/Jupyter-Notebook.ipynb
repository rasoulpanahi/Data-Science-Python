# %% [markdown]
# <h1 style="text-align:center" font-size= 10.5em>Jupyter Notebook</h1>

# %% [markdown]
# ![Markdown Logo is here.](https://www.fullstackpython.com/img/logos/markdown.png)

# %% [markdown]
# # 7 Essential Tips for Writing With Jupyter Notebook
#
# https://towardsdatascience.com/7-essential-tips-for-writing-with-jupyter-notebook-60972a1a8901

# %% [markdown]
#  The Jupyter Notebook renders LaTeX

# %% [markdown]
# $$ \int_a^b \sin(x) dx = -\cos(x)|_a^b$$

# %%
from IPython.display import HTML
from IPython.display import YouTubeVideo

def display_yotube_video(url, **kwargs):
    """
    Displays a Youtube video in a Jupyter notebook.
    
    Args:
        url (string): a link to a Youtube video.
        **kwargs: further arguments for IPython.display.YouTubeVideo
    
    Returns:
        YouTubeVideo: a video that is displayed in your notebook.
    """
    id_ = url.split("=")[-1]
    return YouTubeVideo(id_, **kwargs)

display_yotube_video("https://www.youtube.com/watch?v=UqYde-LULfs", width=800, height=600)

# %% [markdown]
# # Dimensionality Reduction for Data Visualization: PCA vs TSNE vs UMAP vs LDA
